# %% [markdown]
# # Import packages

# %%
# -----------------------------------------------------------------------------
# region import packages

# management
import glob
import pickle
import warnings
warnings.filterwarnings('ignore')
import os
import sys  # print(sys.path)
sys.path.append('/work/ollie/qigao001')
os.chdir('/home/users/qino')

# data analysis
import numpy as np
import xarray as xr
import dask
dask.config.set({"array.slicing.split_large_chunks": True})
# from dask.diagnostics import ProgressBar
# pbar = ProgressBar()
# pbar.register()
from scipy import stats
import xesmf as xe
import pandas as pd
from metpy.interpolate import cross_section
from statsmodels.stats import multitest
import pycircstat as circ
from scipy.stats import circstd
import cmip6_preprocessing.preprocessing as cpp

# plot
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm, ListedColormap
from matplotlib import cm
import cartopy.crs as ccrs
plt.rcParams['pcolor.shading'] = 'auto'
mpl.rcParams['figure.dpi'] = 600
mpl.rc('font', family='Times New Roman', size=10)
mpl.rcParams['axes.linewidth'] = 0.2
plt.rcParams.update({"mathtext.fontset": "stix"})
import matplotlib.animation as animation
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

# self defined
from a_basic_analysis.b_module.mapplot import (
    globe_plot,
    hemisphere_plot,
    quick_var_plot,
    mesh2plot,
    framework_plot1,
    remove_trailing_zero,
    remove_trailing_zero_pos,
)

from a_basic_analysis.b_module.basic_calculations import (
    mon_sea_ann,
    find_ilat_ilon,
    regrid,
    time_weighted_mean,
    find_ilat_ilon_general,
)

from a_basic_analysis.b_module.namelist import (
    month,
    month_num,
    month_dec,
    month_dec_num,
    seasons,
    seasons_last_num,
    hours,
    months,
    month_days,
    zerok,
    panel_labels,
    seconds_per_d,
)

from a_basic_analysis.b_module.source_properties import (
    source_properties,
    calc_lon_diff,
)

from a_basic_analysis.b_module.statistics import (
    fdr_control_bh,
    check_normality_3d,
    check_equal_variance_3d,
    ttest_fdr_control,
)

from a_basic_analysis.b_module.component_plot import (
    cplot_ice_cores,
    plt_mesh_pars,
)

# endregion
# -----------------------------------------------------------------------------

# %% [markdown]
# # import data

# %%
lig_recs = {}

with open('scratch/cmip6/lig/rec/lig_recs_dc.pkl', 'rb') as f:
    lig_recs['DC'] = pickle.load(f)

with open('scratch/cmip6/lig/rec/lig_recs_ec.pkl', 'rb') as f:
    lig_recs['EC'] = pickle.load(f)

with open('scratch/cmip6/lig/rec/lig_recs_jh.pkl', 'rb') as f:
    lig_recs['JH'] = pickle.load(f)

with open('scratch/cmip6/lig/rec/lig_recs_mc.pkl', 'rb') as f:
    lig_recs['MC'] = pickle.load(f)

# %% [markdown]
# # Number of cores

# %% [markdown]
# ## Annual SST

# %%
print(lig_recs['EC']['SO_ann'].shape)
print(lig_recs['JH']['SO_ann'].shape)
print(lig_recs['DC']['annual_128'].shape)
# Out:
# (2, 36)
# (12, 9)
# (20, 17)

# %% [markdown]
# ## Summer SST

# %%
print(lig_recs['EC']['SO_jfm'].shape)
print(lig_recs['JH']['SO_jfm'].shape)
print(lig_recs['DC']['JFM_128'].shape)
print(lig_recs['MC']['interpolated'].shape)
# Out:
# (15, 36)
# (7, 9)
# (21, 17)
# (9, 10)

# %% [markdown]
# # Averaged SST/SAT/SIC anomalies

# %% [markdown]
# ## SO annual SST

# %%
lig_recs['EC']['SO_ann']['127 ka Median PIAn [°C]']
# Out:
# 27    5.13
# 33    2.95
# Name: 127 ka Median PIAn [°C], dtype: float64

# %%
mean_value = np.mean(lig_recs['JH']['SO_ann']['127 ka SST anomaly (°C)'])
std_values = np.std(lig_recs['JH']['SO_ann']['127 ka SST anomaly (°C)'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 2.6 ± 5.1

# %%
mean_value = np.mean(lig_recs['DC']['annual_128']['sst_anom_hadisst_ann'])
std_values = np.std(lig_recs['DC']['annual_128']['sst_anom_hadisst_ann'], ddof = 1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 2.2 ± 1.5

# %% [markdown]
# ## SO summer SST

# %%
mean_value = np.mean(lig_recs['EC']['SO_jfm']['127 ka Median PIAn [°C]'])
std_values = np.std(lig_recs['EC']['SO_jfm']['127 ka Median PIAn [°C]'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 1.7 ± 1.7

# %%
mean_value = np.mean(lig_recs['JH']['SO_jfm']['127 ka SST anomaly (°C)'])
std_values = np.std(lig_recs['JH']['SO_jfm']['127 ka SST anomaly (°C)'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 1.7 ± 3.0

# %%
mean_value = np.mean(lig_recs['DC']['JFM_128']['sst_anom_hadisst_jfm'])
std_values = np.std(lig_recs['DC']['JFM_128']['sst_anom_hadisst_jfm'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 2.2 ± 1.9

# %%
mean_value = np.mean(lig_recs['MC']['interpolated']['sst_anom_hadisst_jfm'])
std_values = np.std(lig_recs['MC']['interpolated']['sst_anom_hadisst_jfm'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 1.2 ± 1.1

# %% [markdown]
# ## AIS SAT

# %%
mean_value = np.mean(lig_recs['EC']['AIS_am']['127 ka Median PIAn [°C]'])
std_values = np.std(lig_recs['EC']['AIS_am']['127 ka Median PIAn [°C]'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# 2.2 ± 1.0

# %% [markdown]
# ## Sep SIC

# %%
mean_value = np.mean(lig_recs['MC']['interpolated']['sic_anom_hadisst_sep'])
std_values = np.std(lig_recs['MC']['interpolated']['sic_anom_hadisst_sep'], ddof=1)

print(str(np.round(mean_value, 1)) + ' ± ' + str(np.round(std_values, 1)))
# Out:
# -41.2 ± 24.9

# %% [markdown]
# # Reconstruction of DC

# %%
# print(lig_recs['DC']['annual_128'].shape)
# print(lig_recs['DC']['JFM_128'].shape)
# len(lig_recs['DC']['annual_128'].Station.unique())
lig_recs['DC']['annual_128']

# lig_recs['DC']['annual_128'].to_csv('scratch/test/annual_128.csv')
# lig_recs['DC']['JFM_128'].to_csv('scratch/test/JFM_128.csv')

# %%
lig_recs['DC']['JFM_128']
# Out:
#         Station           Event Reference (SST proxy reference)  \
# 0      DSDP-593     90-593_Site         McClymont et al. (2016)
# 1        E45-29          E45-29         Howard and Prell (1992)
# 2        E49-17          E49-17         Howard and Prell (1992)
# 3        E49-18          E49-18         Howard and Prell (1992)
# 4    FR1-94-GC3      FR1/94-GC3        De Deckker et al. (2019)
# 5    GeoB3227-5      GeoB3327-5                Ho et al. (2012)
# 6        KH94-4   KH94-4TSP-2PC           Ikehara et al. (1997)
# 7     MD02-2488       MD02-2488             Govin et al. (2009)
# 8     MD02-2588       MD02-2588            Romero et al. (2015)
# 9     MD06-2986       MD06-2986           Hayward et al. (2012)
# 10     MD84-551        MD84-551            Pichon et al. (1992)
# 11    MD97-2120       MD97-2120         Pahnke and Sachs (2006)
# 12    MD97-2121       MD97-2121         Pahnke and Sachs (2006)
# 13  ODP177-1094        177-1094     Bianchi and Gersonde (2002)
# 14  ODP181-1123        181-1123           Hayward et al. (2008)
# 15     PS1768-8        PS1768-8         Zielinski et al. (1998)
# 16     PS2102-2        PS2102-2     Bianchi and Gersonde (2002)
# 17     PS2489-2        PS2489-2     Becquey and Gersonde (2003)
# 18         R657            R657            Weaver et al. (1998)
# 19    SO136-111  SO136_111GC-12            Crosta et al. (2004)
# 20    SO136-GC3     SO136_003GC          Pelejero et al. (2006)
#
#           URL ref (SST proxy reference)   Reference (d18O reference)  \
# 0              doi:10.1002/2016PA002954     Dudley and Nelson (1994)
# 1                 doi:10.1029/91PA02994      Howard and Prell (1992)
# 2                 doi:10.1029/91PA02994      Howard and Prell (1992)
# 3                 doi:10.1029/91PA02994      Howard and Prell (1992)
# 4     doi:10.1080/08120099.2018.1495101     De Deckker et al. (2019)
# 5              doi:10.1029/2012PA002317             Ho et al. (2012)
# 6                 doi:10.1029/97GL00429        Ikehara et al. (1997)
# 7              doi:10.1029/2008PA001603          Govin et al. (2009)
# 8              doi:10.1002/2014PA002636          Starr et al. (2020)
# 9    doi:10.1016/j.marmicro.2011.10.003          Ronge et al. (2015)
# 10                doi:10.1029/92PA00709         Pichon et al. (1992)
# 11             doi:10.1029/2005PA001191         Pahnke et al. (2003)
# 12             doi:10.1029/2005PA001191      Pahnke and Sachs (2006)
# 13    doi:10.1016/S0031-0182(02)00516-3     Hasenfratz et al. (2019)
# 14  doi:10.1016/j.gloplacha.2008.07.003     Elderfield et al. (2012)
# 15                doi:10.1029/98PA01320        Niebler et al. (1995)
# 16    doi:10.1016/S0031-0182(02)00516-3  Bianchi and Gersonde (2002)
# 17             doi:10.1029/2000PA000576  Becquey and Gersonde (2003)
# 18                doi:10.1029/97PA02982         Weaver et al. (1998)
# 19    doi:10.1016/S0377-8398(03)00072-0         Crosta et al. (2004)
# 20     doi:10.1016/j.margeo.2006.04.004        Barrows et al. (2007)
#
#              URL ref (d18O reference)  \
# 0    doi:10.1016/0377-8398(94)90008-6
# 1               doi:10.1029/91PA02994
# 2               doi:10.1029/91PA02994
# 3               doi:10.1029/91PA02994
# 4   doi:10.1080/08120099.2018.1495101
# 5            doi:10.1029/2012PA002317
# 6               doi:10.1029/97GL00429
# 7            doi:10.1029/2008PA001603
# 8          doi:10.1594/PANGAEA.921315
# 9            doi:10.1002/2014PA002727
# 10              doi:10.1029/92PA00709
# 11        doi:10.1126/science.1084451
# 12           doi:10.1029/2005PA001191
# 13        doi:10.1126/science.aat7067
# 14        doi:10.1126/science.1221294
# 15          doi:10.2312/BzP_0167_1995
# 16  doi:10.1016/S0031-0182(02)00516-3
# 17           doi:10.1029/2000PA000576
# 18              doi:10.1029/97PA02982
# 19  doi:10.1016/S0377-8398(03)00072-0
# 20           doi:10.1029/2006PA001328
#
#    Season (A annual, S summer (months JFM))  \
# 0                                         S
# 1                                         S
# 2                                         S
# 3                                         S
# 4                                         S
# 5                                         S
# 6                                         S
# 7                                         S
# 8                                         S
# 9                                         S
# 10                                        S
# 11                                        S
# 12                                        S
# 13                                        S
# 14                                        S
# 15                                        S
# 16                                        S
# 17                                        S
# 18                                        S
# 19                                        S
# 20                                        S
#
#    Proxy (A alkenone UK'37, D diatom as...)  Latitude  Longitude  \
# 0                                         A  -40.5078   167.6745
# 1                                         F  -44.8800  -106.5200
# 2                                         F  -48.2833    90.2500
# 3                                         F  -46.0500    90.1500
# 4                                         F  -44.2600   150.0000
# 5                                         A  -43.2400   -79.9917
# 6                                         A  -48.1400   146.8700
# 7                                         F  -46.4800    88.0200
# 8                                         A  -41.2000    25.5000
# 9                                         F  -43.4485   167.9000
# 10                                        D  -55.0083    73.2817
# 11                                        A  -45.5343   174.9308
# 12                                        A  -40.3800   177.9900
# 13                                        D  -53.1803     5.1303
# 14                                        F  -41.7860  -171.4990
# 15                                        D  -52.5930     4.4760
# 16                                        D  -53.0730    -4.9857
# 17                                        F  -42.8733     8.9733
# 18                                        F  -42.3800   178.4900
# 19                                        D  -56.6810   160.2410
# 20                                        A  -42.2957   169.8780
#
#     SST [°C] (Reconstructed)  Age [ka BP] (Chronology follows Lisiecki a...)  \
# 0                  18.164817                                             128
# 1                  11.123017                                             128
# 2                   8.175265                                             128
# 3                  11.675477                                             128
# 4                  15.722242                                             128
# 5                  14.905477                                             128
# 6                  11.461409                                             128
# 7                   9.733049                                             128
# 8                  17.161237                                             128
# 9                  16.934843                                             128
# 10                  2.696432                                             128
# 11                 13.446370                                             128
# 12                 19.220576                                             128
# 13                  1.869748                                             128
# 14                 17.278963                                             128
# 15                  2.241996                                             128
# 16                  2.185479                                             128
# 17                 11.385108                                             128
# 18                 17.100296                                             128
# 19                  5.289981                                             128
# 20                 17.667617                                             128
#
#     SST anomaly [°C] (Anomaly relative to the World...)  HadISST_JFM  \
# 0                                            1.318002      17.628258
# 1                                            2.002886      12.900438
# 2                                            4.783591       7.093046
# 3                                           -0.344354       8.684106
# 4                                            0.418220      14.188304
# 5                                            0.922223      13.822713
# 6                                            4.316484      10.517632
# 7                                            1.664914       8.829524
# 8                                            5.412864      15.763505
# 9                                            1.427277      16.118504
# 10                                           3.349960       2.170800
# 11                                           2.776395      13.570913
# 12                                           0.654320      17.678131
# 13                                           1.142633       2.024049
# 14                                           0.022796      17.096889
# 15                                           1.263004       2.605473
# 16                                           0.885451       2.273677
# 17                                           0.262715      10.906490
# 18                                           1.790182      16.616945
# 19                                           0.323447       5.572398
# 20                                          -0.155672      16.992069
#
#     sst_anom_hadisst_jfm
# 0               0.536558
# 1              -1.777422
# 2               1.082219
# 3               2.991371
# 4               1.533937
# 5               1.082764
# 6               0.943777
# 7               0.903525
# 8               1.397732
# 9               0.816339
# 10              0.525632
# 11             -0.124542
# 12              1.542445
# 13             -0.154301
# 14              0.182074
# 15             -0.363477
# 16             -0.088198
# 17              0.478618
# 18              0.483351
# 19             -0.282417
# 20              0.675548

# %% [markdown]
# # Reconstruction of EC

# %%
lig_recs['EC']['original']
lig_recs['EC']['SO_ann']
lig_recs['EC']['SO_jfm']
lig_recs['EC']['NH_ann']
lig_recs['EC']['NH_sum']
lig_recs['EC']['GrIS_am']
lig_recs['EC']['AIS_am']
# Out:
#    Station  Latitude  Longitude  Elevation [m]        Area  \
# 43    EDML    -75.00       0.00           2892  Antarctica
# 44     EDC    -75.10     123.35           3233  Antarctica
# 45  Dome F    -77.32      39.70           3810  Antarctica
# 46  Vostok    -78.47     106.87           3488  Antarctica
#
#    Temperature reconstruction method  \
# 43                    Water isotopes
# 44                    Water isotopes
# 45                    Water isotopes
# 46                    Water isotopes
#
#     Uncertainty on temperature reconstruction [°C]                    Type  \
# 43                                             1.5  Annual air temperature
# 44                                             1.5  Annual air temperature
# 45                                             1.5  Annual air temperature
# 46                                             1.5  Annual air temperature
#
#      References temperature data  Surface air temperature [°C]  ...  \
# 43  Masson-Delmotte et al., 2011                         -44.6  ...
# 44  Masson-Delmotte et al., 2011                         -54.5  ...
# 45  Masson-Delmotte et al., 2011                         -57.0  ...
# 46  Masson-Delmotte et al., 2011                         -55.3  ...
#
#     125 ka Median PIAn [°C]  125 ka 2s PIAn [°C]  120 ka Median PIAn [°C]  \
# 43                     0.79                 2.89                    -0.18
# 44                     1.48                 2.98                     1.33
# 45                     1.71                 3.05                     1.01
# 46                     1.48                 2.91                     0.70
#
#     120 ka 2s PIAn [°C]  115 ka Median PIAn [°C]  115 ka 2s PIAn [°C]  \
# 43                 2.88                    -1.54                 2.89
# 44                 2.98                    -1.57                 2.98
# 45                 3.04                    -2.11                 3.05
# 46                 2.90                    -2.17                 2.91
#
#     127-130 ka diff [°C]  127-130 ka diff 2s [°C]  125-127 ka diff [°C]  \
# 43                 -0.46                     0.01                 -0.13
# 44                  0.88                     0.01                 -1.40
# 45                  0.43                     0.13                 -1.57
# 46                  0.46                     0.01                 -0.43
#
#     125-127 ka diff 2s [°C]
# 43                     0.01
# 44                     0.01
# 45                     0.06
# 46                     0.01
#
# [4 rows x 36 columns]

# %% [markdown]
# # Reconstruction of JH

# %%
lig_recs['JH']['original']
lig_recs['JH']['SO_ann']
lig_recs['JH']['SO_jfm']
lig_recs['JH']['NH_ann']
lig_recs['JH']['NH_jas']
# Out:
#        Station          Region  Latitude  Longitude        Type  \
# 0  EW9302-JPC8  North Atlantic     61.00     -25.00  Summer SST
# 1       ODP980  North Atlantic     55.80     -14.11  Summer SST
# 2      NA27-25  North Atlantic     55.57     -14.75  Summer SST
# 3      NEAP18K  North Atlantic     53.00     -30.00  Summer SST
# 4    MD04-2845  North Atlantic     45.35      -5.22  Summer SST
# 5      SU92-03  North Atlantic     43.20     -10.11  Summer SST
# 6     CH69-K09  North Atlantic     41.76     -47.35  Summer SST
# 7    MD95-2040  North Atlantic     40.58      -9.86  Summer SST
# 8      SU90-03  North Atlantic     40.51     -32.05  Summer SST
#
#    HadISST1.1 (1880-1889)  (°C)  Interpolated 127 ka value  (°C)  \
# 0                          9.38                        12.782804
# 1                         11.92                        14.473200
# 2                         11.92                        15.285128
# 3                         10.90                        15.697547
# 4                         15.04                        17.805647
# 5                         15.50                        17.232561
# 6                         16.70                        16.269891
# 7                         16.29                        14.055527
# 8                         19.23                        20.953101
#
#    127 ka SST anomaly (°C)  127 ka 2σ (°C)
# 0                 3.402804        4.312480
# 1                 2.553200        5.029987
# 2                 3.400000        2.896113
# 3                 4.800000        3.667836
# 4                 2.765647        8.285585
# 5                 1.732561        6.281933
# 6                -0.430109        4.321275
# 7                -2.234473        6.689011
# 8                 1.723101        4.590814

# %% [markdown]
# # Reconstruction of MC

# %%
lig_recs['MC'].keys()
# Out:
# dict_keys(['original', 'interpolated'])

# %%
lig_recs['MC']['original']
# Out:
#       Station  Latitude  Longitude  Depth (cmbsf)  \
# 0    ANTA91-8    -70.78     172.83          272.0
# 1    ANTA91-8    -70.78     172.83          274.0
# 2    ANTA91-8    -70.78     172.83          276.0
# 3    ANTA91-8    -70.78     172.83          278.0
# 4    ANTA91-8    -70.78     172.83          280.0
# ..        ...       ...        ...            ...
# 140    U1361A    -64.41     143.89          211.0
# 141    U1361A    -64.41     143.89          213.0
# 142    U1361A    -64.41     143.89          217.0
# 143    U1361A    -64.41     143.89          222.0
# 144    U1361A    -64.41     143.89          230.0
#
#      Age on AICC2012 chronology (ka)  MAT September sea-ice concentration (%)  \
# 0                         121.214074                                    38.62
# 1                         121.980200                                    33.33
# 2                         122.746326                                    38.15
# 3                         123.512452                                    34.66
# 4                         124.278578                                    49.13
# ..                               ...                                      ...
# 140                       129.261692                                    23.70
# 141                       130.817010                                    76.40
# 142                       133.284836                                    35.80
# 143                       135.567196                                    53.10
# 144                       139.220372                                    45.00
#
#      MAT summer SST (degrees celsius)
# 0                                1.08
# 1                                0.99
# 2                                0.96
# 3                                1.04
# 4                                0.75
# ..                                ...
# 140                              2.40
# 141                              0.40
# 142                              2.20
# 143                              0.70
# 144                              0.50
#
# [145 rows x 7 columns]

# %%
lig_recs['MC']['interpolated'].to_csv('scratch/test/interpolated.csv')
